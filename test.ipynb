# %%
from hoopin.load_data import load_data
# from .hoopin.load_data import load_data2
from hoopin.visualization import show_heatmap
from hoopin.visualization import show_visualizations
from hoopin.analysis import select_columns
import pandas as pd
import seaborn as sns


# data   = pd.read_csv('./hoopin/datasets/basketball.csv')
# selected_columns = select_columns()

# %%
# show_visualizations()
alldata1 = load_data.load_data()
alldata1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 2
#       1 # show_visualizations()
# ----> 2 alldata1 = load_data.load_data()
#       3 alldata1
#
# AttributeError: module 'hoopin.load_data' has no attribute 'load_data'

# %%
# data = pd.read_csv('hoopin/datasets/basketball.csv')
data= load_data2()

# %%
import pkg_resources

path = 'data/basketball.csv'
data_path = pkg_resources.resource_filename('Hoopin', path)
data_path

# %%
# data = pd.read_csv('hoopin/datasets/basketball.csv')
data= load_data2()

# %%
data
# Out:
#      Unnamed: 0    Rk                  Team   G     MP    FG   FGA    FG%  \
# 0             0   1.0   Cleveland Cavaliers  82  242.4  39.0  83.5  0.468
# 1             1   2.0            Miami Heat  82  241.5  40.1  83.2  0.482
# 2             2   3.0    Philadelphia 76ers  82  242.4  40.4  85.4  0.473
# 3             3   4.0        Boston Celtics  82  243.7  41.8  90.2  0.463
# 4             4   5.0       Toronto Raptors  82  241.5  40.4  82.3  0.491
# ..          ...   ...                   ...  ..    ...   ...   ...    ...
# 175          25  26.0   Cleveland Cavaliers  82  240.6  41.8  88.3  0.474
# 176          26  27.0         Chicago Bulls  82  242.1  41.0  86.8  0.472
# 177          27  28.0         Brooklyn Nets  82  242.1  41.7  89.4  0.466
# 178          28  29.0  New Orleans Pelicans  82  243.4  41.7  91.9  0.454
# 179          29  30.0          Phoenix Suns  82  240.3  41.8  88.7  0.471
#
#        3P   3PA  ...   TOV    PF    PTS   Age   MOV   Pace    TS%     W     L  \
# 0    11.3  30.6  ...  15.7  20.4  106.9  25.4  5.38   95.7  0.590  51.0  31.0
# 1    13.1  35.8  ...  15.7  20.0  109.8  27.7 -0.32   96.3  0.574  44.0  38.0
# 2    11.6  33.4  ...  14.3  19.6  110.9  28.2  4.32   96.9  0.608  54.0  28.0
# 3    11.6  33.7  ...  12.7  19.1  111.4  27.4  6.52   98.5  0.600  57.0  25.0
# 4    12.2  32.6  ...  16.7  19.6  111.4  25.8  1.48   97.1  0.555  41.0  41.0
# ..    ...   ...  ...   ...   ...    ...   ...   ...    ...    ...   ...   ...
# 175  11.7  31.7  ...  13.5  20.7  109.9  30.6  0.94   98.0  0.584  50.0  32.0
# 176  12.1  32.7  ...  13.6  17.4  110.0  24.4 -7.04   98.3  0.529  27.0  55.0
# 177   9.0  24.5  ...  12.4  19.7  110.3  25.1 -3.74   98.9  0.551  28.0  54.0
# 178  10.9  30.6  ...  14.5  20.4  110.4  27.6  1.30  100.5  0.573  48.0  34.0
# 179  10.9  29.2  ...  13.4  20.9  113.3  23.7 -9.37  100.3  0.532  21.0  61.0
#
#      Year
# 0    2023
# 1    2023
# 2    2023
# 3    2023
# 4    2023
# ..    ...
# 175  2018
# 176  2018
# 177  2018
# 178  2018
# 179  2018
#
# [180 rows x 33 columns]

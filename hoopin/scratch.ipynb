# %%
import pandas as pd
import pkg_resources

# all_data_1 =  pd.read_csv("datasets/basketball.csv")

# %%
all_data_1
# Out:
#      Unnamed: 0    Rk                  Team   G  ...    TS%     W     L  Year
# 0             0   1.0   Cleveland Cavaliers  82  ...  0.590  51.0  31.0  2023
# 1             1   2.0            Miami Heat  82  ...  0.574  44.0  38.0  2023
# 2             2   3.0    Philadelphia 76ers  82  ...  0.608  54.0  28.0  2023
# 3             3   4.0        Boston Celtics  82  ...  0.600  57.0  25.0  2023
# 4             4   5.0       Toronto Raptors  82  ...  0.555  41.0  41.0  2023
# ..          ...   ...                   ...  ..  ...    ...   ...   ...   ...
# 175          25  26.0   Cleveland Cavaliers  82  ...  0.584  50.0  32.0  2018
# 176          26  27.0         Chicago Bulls  82  ...  0.529  27.0  55.0  2018
# 177          27  28.0         Brooklyn Nets  82  ...  0.551  28.0  54.0  2018
# 178          28  29.0  New Orleans Pelicans  82  ...  0.573  48.0  34.0  2018
# 179          29  30.0          Phoenix Suns  82  ...  0.532  21.0  61.0  2018
#
# [180 rows x 33 columns]

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35],
        'City': ['New York', 'San Francisco', 'Los Angeles']}

all_data = pd.DataFrame(data)

# %%
path = 'data'

data_path = pkg_resources.resource_filename('hoopin', path)
data_path
# Out:
# 'c:\\Users\\Public\\miniconda3\\Lib\\site-packages\\hoopin\\data'

# %%
all_data.to_csv("data/basketball1")
